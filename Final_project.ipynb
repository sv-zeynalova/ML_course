# %%
import pandas as pd

# %%
flights = pd.read_csv('flights.csv',low_memory=False)
airports = pd.read_csv('airports.csv')
airlines = pd.read_csv('airlines.csv')

all_features = flights.columns.values
all_features
# Out:
# array(['YEAR', 'MONTH', 'DAY', 'DAY_OF_WEEK', 'AIRLINE', 'FLIGHT_NUMBER',
#        'TAIL_NUMBER', 'ORIGIN_AIRPORT', 'DESTINATION_AIRPORT',
#        'SCHEDULED_DEPARTURE', 'DEPARTURE_TIME', 'DEPARTURE_DELAY',
#        'TAXI_OUT', 'WHEELS_OFF', 'SCHEDULED_TIME', 'ELAPSED_TIME',
#        'AIR_TIME', 'DISTANCE', 'WHEELS_ON', 'TAXI_IN',
#        'SCHEDULED_ARRIVAL', 'ARRIVAL_TIME', 'ARRIVAL_DELAY', 'DIVERTED',
#        'CANCELLED', 'CANCELLATION_REASON', 'AIR_SYSTEM_DELAY',
#        'SECURITY_DELAY', 'AIRLINE_DELAY', 'LATE_AIRCRAFT_DELAY',
#        'WEATHER_DELAY'], dtype=object)

# %%
# Восстанавливаем данные по аэропортам прибытия и отправления, т.к. часть данных указана кодом в 3х-значном формате и часть в формате ID
aircode1 = pd.read_csv('L_AIRPORT.csv')
aircode2 = pd.read_csv('L_AIRPORT_ID.csv')

aircode1 = aircode1.reset_index()
aircode2 = aircode2.reset_index()
aircodes = pd.merge(aircode1,aircode2,on='Description')
aircode_dict = dict(zip(aircodes['Code_y'].astype(str),aircodes['Code_x']))

# %%
# Необходимо, чтобы все аэропорты отправления и прибытия являлись строками
flights['ORIGIN_AIRPORT'] = flights['ORIGIN_AIRPORT'].values.astype(str)
flights['DESTINATION_AIRPORT'] = flights['DESTINATION_AIRPORT'].values.astype(str)

for i in range(len(flights)):
    if len(flights['ORIGIN_AIRPORT'][i]) != 3:
        to_replace = flights['ORIGIN_AIRPORT'][i]
        value = aircode_dict[flights['ORIGIN_AIRPORT'][i]]
        flights = flights.replace(to_replace, value)
for i in range(len(flights)):
    if len(flights['DESTINATION_AIRPORT'][i]) != 3:
        to_replace = flights['DESTINATION_AIRPORT'][i]
        value = aircode_dict[flights['DESTINATION_AIRPORT'][i]]
        flights = flights.replace(to_replace, value)

# %%
len(flights['ORIGIN_AIRPORT'][i]) != 3
# Out:
# False

# %%
len(flights['DESTINATION_AIRPORT'][i]) != 3
# Out:
# False

# %%
flights.shape
# Out:
# (5819079, 31)

# %%
df = flights.merge(airlines, left_on = 'AIRLINE',right_on = 'IATA_CODE')
df.shape
# Out:
# (5819079, 33)

# %%
df_all = df.merge(airports, left_on = ['ORIGIN_AIRPORT'], right_on = ['IATA_CODE'],how = 'outer')

df_all.shape
# Out:
# (5819079, 40)

# %%
df_all['DATE'] = pd.to_datetime(df[['YEAR','MONTH','DAY']],dayfirst=True)
df_all.drop(['YEAR','MONTH','DAY'],axis=1,inplace = True)

# %%
#!pip install sweetviz
import sweetviz as sv

my_report = sv.analyze(df_all)
my_report.show_html()
# Out:
#                                              |      | [  0%]   00:00 -> (? left)
# Report SWEETVIZ_REPORT.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
df_all.drop_duplicates(inplace=True)

# %%
df_group = df_all.groupby(['ORIGIN_AIRPORT','AIRLINE_y'])['DEPARTURE_DELAY'].mean().reset_index().sort_values(by = 'DEPARTURE_DELAY')
df_group
# Out:
#      ORIGIN_AIRPORT                    AIRLINE_y  DEPARTURE_DELAY
# 1308            XNA       American Airlines Inc.        -7.055556
# 4               ABQ         Alaska Airlines Inc.        -6.709589
# 857             MTJ  Atlantic Southeast Airlines        -6.086093
# 1313            YAK         Alaska Airlines Inc.        -6.070932
# 276             CNY        Skywest Airlines Inc.        -6.058537
# ...             ...                          ...              ...
# 174             BTR        United Air Lines Inc.        56.000000
# 1276            TUL               Virgin America       113.000000
# 199             BWI        Skywest Airlines Inc.       156.000000
# 411             EWR        Skywest Airlines Inc.       299.500000
# 298             CVG        United Air Lines Inc.       302.333333
#
# [1315 rows x 3 columns]

# %%
df_all_merge = df_all.merge(df_group, how='left', on = ['ORIGIN_AIRPORT', 'AIRLINE_y'])

# %%
df_all_merge[df_all_merge.DEPARTURE_DELAY_x.isna()]
# Out:
#          DAY_OF_WEEK AIRLINE_x  FLIGHT_NUMBER TAIL_NUMBER ORIGIN_AIRPORT  \
# 3                  4        AS            136      N431AS            ANC
# 233                3        AS             45      N763AS            ANC
# 349                7        AS            144      N535AS            ANC
# 400                1        AS             49      N765AS            ANC
# 811                7        AS            106      N767AS            ANC
# ...              ...       ...            ...         ...            ...
# 5816785            7        WN           3209         NaN            ISP
# 5818304            5        WN           1500      N792SW            ISP
# 5818317            6        WN           1434      N7752B            ISP
# 5818418            7        WN            605         NaN            ISP
# 5818455            2        WN           2735      N7729A            ISP
#
#         DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  DEPARTURE_TIME  \
# 3                       SEA                  135             NaN
# 233                     BET                 1905             NaN
# 349                     PDX                  200             NaN
# 400                     ADQ                 1530             NaN
# 811                     SEA                 2140             NaN
# ...                     ...                  ...             ...
# 5816785                 BWI                  615             NaN
# 5818304                 BWI                  935             NaN
# 5818317                 BWI                 1215             NaN
# 5818418                 BWI                  505             NaN
# 5818455                 BWI                 1420             NaN
#
#          DEPARTURE_DELAY_x  TAXI_OUT  ...               AIRLINE_y  \
# 3                      NaN       NaN  ...    Alaska Airlines Inc.
# 233                    NaN       NaN  ...    Alaska Airlines Inc.
# 349                    NaN       NaN  ...    Alaska Airlines Inc.
# 400                    NaN       NaN  ...    Alaska Airlines Inc.
# 811                    NaN       NaN  ...    Alaska Airlines Inc.
# ...                    ...       ...  ...                     ...
# 5816785                NaN       NaN  ...  Southwest Airlines Co.
# 5818304                NaN       NaN  ...  Southwest Airlines Co.
# 5818317                NaN       NaN  ...  Southwest Airlines Co.
# 5818418                NaN       NaN  ...  Southwest Airlines Co.
# 5818455                NaN       NaN  ...  Southwest Airlines Co.
#
#          IATA_CODE_y                                      AIRPORT       CITY  \
# 3                ANC  Ted Stevens Anchorage International Airport  Anchorage
# 233              ANC  Ted Stevens Anchorage International Airport  Anchorage
# 349              ANC  Ted Stevens Anchorage International Airport  Anchorage
# 400              ANC  Ted Stevens Anchorage International Airport  Anchorage
# 811              ANC  Ted Stevens Anchorage International Airport  Anchorage
# ...              ...                                          ...        ...
# 5816785          ISP                Long Island MacArthur Airport      Islip
# 5818304          ISP                Long Island MacArthur Airport      Islip
# 5818317          ISP                Long Island MacArthur Airport      Islip
# 5818418          ISP                Long Island MacArthur Airport      Islip
# 5818455          ISP                Long Island MacArthur Airport      Islip
#
#          STATE  COUNTRY  LATITUDE  LONGITUDE       DATE  DEPARTURE_DELAY_y
# 3           AK      USA  61.17432 -149.99619 2015-01-01           0.455896
# 233         AK      USA  61.17432 -149.99619 2015-01-01           0.455896
# 349         AK      USA  61.17432 -149.99619 2015-01-01           0.455896
# 400         AK      USA  61.17432 -149.99619 2015-01-01           0.455896
# 811         AK      USA  61.17432 -149.99619 2015-01-02           0.455896
# ...        ...      ...       ...        ...        ...                ...
# 5816785     NY      USA  40.79524  -73.10021 2015-12-22          10.078287
# 5818304     NY      USA  40.79524  -73.10021 2015-12-30          10.078287
# 5818317     NY      USA  40.79524  -73.10021 2015-12-30          10.078287
# 5818418     NY      USA  40.79524  -73.10021 2015-12-31          10.078287
# 5818455     NY      USA  40.79524  -73.10021 2015-12-31          10.078287
#
# [85576 rows x 39 columns]

# %%
df_all_merge.loc[df_all_merge.DEPARTURE_DELAY_x.isna(),'DEPARTURE_DELAY_x'] = df_all_merge.DEPARTURE_DELAY_y

# %%
df_all_merge[df_all_merge.DEPARTURE_DELAY_x.isna()]
#df_all_merge.DEPARTURE_DELAY_x.isna().sum()
# Out:
# Empty DataFrame
# Columns: [DAY_OF_WEEK, AIRLINE_x, FLIGHT_NUMBER, TAIL_NUMBER, ORIGIN_AIRPORT, DESTINATION_AIRPORT, SCHEDULED_DEPARTURE, DEPARTURE_TIME, DEPARTURE_DELAY_x, TAXI_OUT, WHEELS_OFF, SCHEDULED_TIME, ELAPSED_TIME, AIR_TIME, DISTANCE, WHEELS_ON, TAXI_IN, SCHEDULED_ARRIVAL, ARRIVAL_TIME, ARRIVAL_DELAY, DIVERTED, CANCELLED, CANCELLATION_REASON, AIR_SYSTEM_DELAY, SECURITY_DELAY, AIRLINE_DELAY, LATE_AIRCRAFT_DELAY, WEATHER_DELAY, IATA_CODE_x, AIRLINE_y, IATA_CODE_y, AIRPORT, CITY, STATE, COUNTRY, LATITUDE, LONGITUDE, DATE, DEPARTURE_DELAY_y]
# Index: []
#
# [0 rows x 39 columns]

# %%
del df_all_merge['DEPARTURE_DELAY_y']

# %%
df_all_merge.shape
# Out:
# (5818485, 38)

# %%
df_grouped = df_all_merge.groupby(['ORIGIN_AIRPORT','AIRPORT'])['DEPARTURE_DELAY_x'].mean().reset_index().sort_values(by = 'DEPARTURE_DELAY_x')
df_grouped.query('DEPARTURE_DELAY_x>0').head()
# Out:
#     ORIGIN_AIRPORT                          AIRPORT  DEPARTURE_DELAY_x
# 46             BTM              Bert Mooney Airport           0.131171
# 10             ADQ                   Kodiak Airport           0.268817
# 43             BRD  Brainerd Lakes Regional Airport           0.348031
# 89             DLG               Dillingham Airport           0.558442
# 184            LIH                    Lihue Airport           0.598528

# %% [markdown]
# ## Аэропорт с минимальной задержкой вылета (в среднем) - Bert Mooney Airport

# %%
airports = airports.query('CITY == "Los Angeles"')
airports
# Out:
#     IATA_CODE                            AIRPORT         CITY STATE COUNTRY  \
# 176       LAX  Los Angeles International Airport  Los Angeles    CA     USA
#
#      LATITUDE  LONGITUDE
# 176  33.94254 -118.40807

# %%
df_all_merge.ARRIVAL_DELAY.isna().sum()
# Out:
# 104494

# %%
df_group_arrival = df_all_merge.groupby(['DESTINATION_AIRPORT','AIRLINE_y'])['ARRIVAL_DELAY'].mean().reset_index().sort_values(by = 'ARRIVAL_DELAY')
df_group_arrival
# Out:
#     DESTINATION_AIRPORT                    AIRLINE_y  ARRIVAL_DELAY
# 503                 GSO              US Airways Inc.     -23.000000
# 192                 BUR        United Air Lines Inc.     -22.000000
# 227                 CHS         Alaska Airlines Inc.     -18.692308
# 620                 JFK         Alaska Airlines Inc.     -18.542056
# 4                   ABQ         Alaska Airlines Inc.     -15.789041
# ..                  ...                          ...            ...
# 302                 DAB  Atlantic Southeast Airlines      41.000000
# 710                 LIT       American Airlines Inc.      42.875000
# 304                 DAB              US Airways Inc.      44.000000
# 119                 BMI       Frontier Airlines Inc.      44.444444
# 467                 GEG       Frontier Airlines Inc.      87.333333
#
# [1316 rows x 3 columns]

# %%
df_all_merge_arrival = df_all_merge.merge(df_group_arrival, how='left', on = ['DESTINATION_AIRPORT', 'AIRLINE_y'])

# %%
df_all_merge_arrival.loc[df_all_merge_arrival.ARRIVAL_DELAY_x.isna(),'ARRIVAL_DELAY_x'] = df_all_merge_arrival.ARRIVAL_DELAY_y

# %%
df_all_merge_arrival[df_all_merge_arrival.ARRIVAL_DELAY_x.isna()]
# Out:
# Empty DataFrame
# Columns: [DAY_OF_WEEK, AIRLINE_x, FLIGHT_NUMBER, TAIL_NUMBER, ORIGIN_AIRPORT, DESTINATION_AIRPORT, SCHEDULED_DEPARTURE, DEPARTURE_TIME, DEPARTURE_DELAY_x, TAXI_OUT, WHEELS_OFF, SCHEDULED_TIME, ELAPSED_TIME, AIR_TIME, DISTANCE, WHEELS_ON, TAXI_IN, SCHEDULED_ARRIVAL, ARRIVAL_TIME, ARRIVAL_DELAY_x, DIVERTED, CANCELLED, CANCELLATION_REASON, AIR_SYSTEM_DELAY, SECURITY_DELAY, AIRLINE_DELAY, LATE_AIRCRAFT_DELAY, WEATHER_DELAY, IATA_CODE_x, AIRLINE_y, IATA_CODE_y, AIRPORT, CITY, STATE, COUNTRY, LATITUDE, LONGITUDE, DATE, ARRIVAL_DELAY_y]
# Index: []
#
# [0 rows x 39 columns]

# %%
del df_all_merge_arrival['ARRIVAL_DELAY_y']

# %%
df_grouped_arrival = df_all_merge_arrival.query('DESTINATION_AIRPORT == "LAX"').groupby(['AIRLINE_y'])['ARRIVAL_DELAY_x'].mean().reset_index().sort_values(by = 'ARRIVAL_DELAY_x')
df_grouped_arrival.head()
# Out:
#                 AIRLINE_y  ARRIVAL_DELAY_x
# 5  Hawaiian Airlines Inc.        -4.653317
# 0    Alaska Airlines Inc.        -0.525700
# 6         JetBlue Airways        -0.022152
# 3    Delta Air Lines Inc.         1.398882
# 1  American Airlines Inc.         2.122856

# %% [markdown]
# ## Cамая пунктуальная авиакомпания по прилету в аэропорт Los Angeles - Hawaiian Airlines Inc. (прилетает раньше запланированного - с позиции пассажира это лучше, быстрее). Если рассматривать как с позиции пассажира, так и с позиции бизнеса- это Jet Blue Airways

# %%
df_all_merge_arrival.isna().sum()
# Out:
# DAY_OF_WEEK                  0
# AIRLINE_x                    0
# FLIGHT_NUMBER                0
# TAIL_NUMBER              14234
# ORIGIN_AIRPORT               0
# DESTINATION_AIRPORT          0
# SCHEDULED_DEPARTURE          0
# DEPARTURE_TIME           85576
# DEPARTURE_DELAY_x            0
# TAXI_OUT                 88470
# WHEELS_OFF               88470
# SCHEDULED_TIME               6
# ELAPSED_TIME            104494
# AIR_TIME                104494
# DISTANCE                     0
# WHEELS_ON                91936
# TAXI_IN                  91936
# SCHEDULED_ARRIVAL            0
# ARRIVAL_TIME             91936
# ARRIVAL_DELAY_x              0
# DIVERTED                     0
# CANCELLED                    0
# CANCELLATION_REASON    5729178
# AIR_SYSTEM_DELAY       4755046
# SECURITY_DELAY         4755046
# AIRLINE_DELAY          4755046
# LATE_AIRCRAFT_DELAY    4755046
# WEATHER_DELAY          4755046
# IATA_CODE_x                  0
# AIRLINE_y                    0
# IATA_CODE_y               4021
# AIRPORT                   4021
# CITY                      4021
# STATE                     4021
# COUNTRY                   4021
# LATITUDE                  9028
# LONGITUDE                 9028
# DATE                         0
# dtype: int64

# %%
df_taxi_grouped = df_all_merge_arrival.groupby(['ORIGIN_AIRPORT','AIRLINE_y'])['TAXI_OUT'].mean().reset_index().sort_values(by = 'TAXI_OUT')

# %%
df_taxi_grouped
# Out:
#     ORIGIN_AIRPORT                    AIRLINE_y   TAXI_OUT
# 28             AGS        United Air Lines Inc.   5.000000
# 276            CNY        Skywest Airlines Inc.   6.512195
# 22             ADQ         Alaska Airlines Inc.   6.591398
# 158            BRW         Alaska Airlines Inc.   6.901982
# 707            LIH       Hawaiian Airlines Inc.   7.021047
# ..             ...                          ...        ...
# 693            LGA         Delta Air Lines Inc.  29.071429
# 623            JFK         Delta Air Lines Inc.  29.455759
# 692            LGA  Atlantic Southeast Airlines  31.492079
# 455            FSD        United Air Lines Inc.  33.000000
# 367            DSM              US Airways Inc.  37.000000
#
# [1315 rows x 3 columns]

# %%
df_taxi = df_all_merge_arrival.merge(df_taxi_grouped, how='left', on = ['ORIGIN_AIRPORT', 'AIRLINE_y'])

# %%
df_taxi.loc[df_taxi.TAXI_OUT_x.isna(),'TAXI_OUT_x'] = df_taxi.TAXI_OUT_y

# %%
#df_taxi.TAXI_OUT_x.isna().sum()

# %%
del df_taxi['TAXI_OUT_y']

# %%
airport_counts = df_taxi.ORIGIN_AIRPORT.value_counts()
airport_counts
# Out:
# ATL    379418
# ORD    313500
# DFW    260588
# DEN    214186
# LAX    212395
#         ...
# STC        83
# DLG        77
# GST        77
# AKN        63
# ITH        34
# Name: ORIGIN_AIRPORT, Length: 323, dtype: int64

# %%
df_taxi.reset_index()
df_taxi_out = (df_taxi.groupby(['ORIGIN_AIRPORT'])['TAXI_OUT_x'].sum()/df_taxi.ORIGIN_AIRPORT.value_counts()).sort_values(ascending = False)

# %%
df_taxi_out
# Out:
# LGA    26.733558
# JFK    26.728848
# ITH    22.514706
# PHL    21.554212
# ISN    20.950977
#          ...
# BET     7.152490
# VEL     7.100000
# BRW     6.901982
# ADQ     6.591398
# CNY     6.512195
# Length: 323, dtype: float64

# %%
df_taxi.query('ORIGIN_AIRPORT == "LGA"').head(1)
# Out:
#          DAY_OF_WEEK AIRLINE_x  FLIGHT_NUMBER TAIL_NUMBER ORIGIN_AIRPORT  \
# 4274714            4        AA           1103      N3HCAA            LGA
#
#         DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  DEPARTURE_TIME  \
# 4274714                 DFW                  600             NaN
#
#          DEPARTURE_DELAY_x  TAXI_OUT_x  ...  IATA_CODE_x  \
# 4274714           6.406137   25.258086  ...           AA
#
#                       AIRLINE_y  IATA_CODE_y  \
# 4274714  American Airlines Inc.          LGA
#
#                                          AIRPORT      CITY  STATE  COUNTRY  \
# 4274714  LaGuardia Airport (Marine Air Terminal)  New York     NY      USA
#
#          LATITUDE  LONGITUDE       DATE
# 4274714  40.77724  -73.87261 2015-07-05
#
# [1 rows x 38 columns]

# %% [markdown]
# ## Аэропорт с самой большой долей руления на самолетовылет - LaGuardia Airport (Marine Air Terminal) г.Нью-Йорк

# %%
my_report = sv.analyze(df_taxi)
my_report.show_html()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/bm/glmrb3ps3c14r341qn4q03hc0000gn/T/ipykernel_2725/3306381050.py in <module>
# ----> 1 my_report = sv.analyze(df_taxi)
#       2 my_report.show_html()
#
# NameError: name 'sv' is not defined

# %% [markdown]
# ## Будем строить прогноз по показателю ARRIVAL_DELAY_x. После формирования отчета смотрим фичи, где отсутствует корреляция и удаляем из датасета

# %%
df_new = df_taxi.drop(['CANCELLATION_REASON', 'CANCELLED','COUNTRY', 'DIVERTED', 'FLIGHT_NUMBER', 'TAIL_NUMBER', 'ELAPSED_TIME','AIR_TIME', 'SECURITY_DELAY','LATITUDE','LONGITUDE'], axis=1)

# %%
df_new.isna().sum()
# Out:
# DAY_OF_WEEK                  0
# AIRLINE_x                    0
# ORIGIN_AIRPORT               0
# DESTINATION_AIRPORT          0
# SCHEDULED_DEPARTURE          0
# DEPARTURE_TIME           85576
# DEPARTURE_DELAY_x            0
# TAXI_OUT_x                   0
# WHEELS_OFF               88470
# SCHEDULED_TIME               6
# DISTANCE                     0
# WHEELS_ON                91936
# TAXI_IN                  91936
# SCHEDULED_ARRIVAL            0
# ARRIVAL_TIME             91936
# ARRIVAL_DELAY_x              0
# AIR_SYSTEM_DELAY       4755046
# AIRLINE_DELAY          4755046
# LATE_AIRCRAFT_DELAY    4755046
# WEATHER_DELAY          4755046
# IATA_CODE_x                  0
# AIRLINE_y                    0
# IATA_CODE_y               4021
# AIRPORT                   4021
# CITY                      4021
# STATE                     4021
# DATE                         0
# dtype: int64

# %% [markdown]
# ## Также удалим данные, где очень много пропусков:
# # AIR_SYSTEM_DELAY, AIRLINE_DELAY, LATE_AIRCRAFT_DELAY, AIR_SYSTEM_DELAY имеют большой вес влияния на показатель, но 82% пропусков - пока удалим (либо посчитать среднее в зависимости от авиакомпании)
# ## WEATHER_DELAY - 82% пропусков, но 93,9% значений = 0, поэтому заменим на 0 (т.к. влияние данного значения на показатель ARRIVAL_DELAY_x = 0,26
# ## 4021 пропуск  в данных по аэропорту BSM, заменим на данные из интернета Austin, TX [Bergstrom Air Rescue Service Airport], USA

# %%
df_taxi[df_taxi.AIRPORT.isna()]
# Out:
#          DAY_OF_WEEK AIRLINE_x  FLIGHT_NUMBER TAIL_NUMBER ORIGIN_AIRPORT  \
# 4182376            4        AS            671      N423AS            BSM
# 4182377            5        AS            671      N402AS            BSM
# 4182378            6        AS            671      N423AS            BSM
# 4182379            7        AS            671      N305AS            BSM
# 4182380            1        AS            671      N483AS            BSM
# ...              ...       ...            ...         ...            ...
# 4186392            6        VX            440      N530VA            BSM
# 4186393            6        VX            219      N846VA            BSM
# 4186394            6        VX            721      N525VA            BSM
# 4186395            6        VX            449      N523VA            BSM
# 4186396            6        VX            450      N846VA            BSM
#
#         DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  DEPARTURE_TIME  \
# 4182376                 SEA                 1840          1837.0
# 4182377                 SEA                 1840          1830.0
# 4182378                 SEA                 1840          1835.0
# 4182379                 SEA                 1840          1835.0
# 4182380                 SEA                 1840          1831.0
# ...                     ...                  ...             ...
# 4186392                 DAL                  715             NaN
# 4186393                 SFO                  740             NaN
# 4186394                 DAL                 1020          1113.0
# 4186395                 DAL                 1355          1407.0
# 4186396                 DAL                 1800          1800.0
#
#          DEPARTURE_DELAY_x  TAXI_OUT_x  ...  IATA_CODE_x  \
# 4182376          -3.000000   10.000000  ...           AS
# 4182377         -10.000000   12.000000  ...           AS
# 4182378          -5.000000    8.000000  ...           AS
# 4182379          -5.000000    9.000000  ...           AS
# 4182380          -9.000000   13.000000  ...           AS
# ...                    ...         ...  ...          ...
# 4186392           7.380117   11.900585  ...           VX
# 4186393           7.380117   11.900585  ...           VX
# 4186394          53.000000   24.000000  ...           VX
# 4186395          12.000000   19.000000  ...           VX
# 4186396           0.000000   11.000000  ...           VX
#
#                     AIRLINE_y  IATA_CODE_y  AIRPORT  CITY  STATE  COUNTRY  \
# 4182376  Alaska Airlines Inc.          NaN      NaN   NaN    NaN      NaN
# 4182377  Alaska Airlines Inc.          NaN      NaN   NaN    NaN      NaN
# 4182378  Alaska Airlines Inc.          NaN      NaN   NaN    NaN      NaN
# 4182379  Alaska Airlines Inc.          NaN      NaN   NaN    NaN      NaN
# 4182380  Alaska Airlines Inc.          NaN      NaN   NaN    NaN      NaN
# ...                       ...          ...      ...   ...    ...      ...
# 4186392        Virgin America          NaN      NaN   NaN    NaN      NaN
# 4186393        Virgin America          NaN      NaN   NaN    NaN      NaN
# 4186394        Virgin America          NaN      NaN   NaN    NaN      NaN
# 4186395        Virgin America          NaN      NaN   NaN    NaN      NaN
# 4186396        Virgin America          NaN      NaN   NaN    NaN      NaN
#
#          LATITUDE  LONGITUDE       DATE
# 4182376       NaN        NaN 2015-03-18
# 4182377       NaN        NaN 2015-03-18
# 4182378       NaN        NaN 2015-03-18
# 4182379       NaN        NaN 2015-03-18
# 4182380       NaN        NaN 2015-03-18
# ...           ...        ...        ...
# 4186392       NaN        NaN 2015-03-23
# 4186393       NaN        NaN 2015-03-23
# 4186394       NaN        NaN 2015-03-23
# 4186395       NaN        NaN 2015-03-23
# 4186396       NaN        NaN 2015-03-23
#
# [4021 rows x 38 columns]

# %%
df_taxi[df_taxi.AIRPORT.isna()].ORIGIN_AIRPORT.unique()
# Out:
# array(['BSM'], dtype=object)

# %%
df_new.IATA_CODE_y.fillna('BSM',inplace = True)
df_new.AIRPORT.fillna('Austin, TX [Bergstrom Air Rescue Service Airport]',inplace = True)
df_new.CITY.fillna('Austin',inplace = True)
df_new.STATE.fillna('Texas',inplace = True)

# %%
df_new.drop(['AIR_SYSTEM_DELAY','AIRLINE_DELAY','LATE_AIRCRAFT_DELAY'],axis=1, inplace=True)

# %%
df_new['WEATHER_DELAY'].fillna(0,inplace = True)

# %% [markdown]
# ### хотела заполнить пропуски, но не смогла перевести данные колонки в часы и минуты

# %%
#df_new.loc[df_new.DEPARTURE_TIME.isna(),'DEPARTURE_TIME'] = df_new['SCHEDULED_DEPARTURE'] + df_new['DEPARTURE_DELAY_x']

# %%
df_new.isna().sum()
# Out:
# DAY_OF_WEEK                0
# AIRLINE_x                  0
# ORIGIN_AIRPORT             0
# DESTINATION_AIRPORT        0
# SCHEDULED_DEPARTURE        0
# DEPARTURE_TIME         85576
# DEPARTURE_DELAY_x          0
# TAXI_OUT_x                 0
# WHEELS_OFF             88470
# SCHEDULED_TIME             6
# DISTANCE                   0
# WHEELS_ON              91936
# TAXI_IN                91936
# SCHEDULED_ARRIVAL          0
# ARRIVAL_TIME           91936
# ARRIVAL_DELAY_x            0
# WEATHER_DELAY              0
# IATA_CODE_x                0
# AIRLINE_y                  0
# IATA_CODE_y                0
# AIRPORT                    0
# CITY                       0
# STATE                      0
# DATE                       0
# dtype: int64

# %%
# Удалим нулевые строки из датасета, но проверим, сколько мы потеряем информации после удаления

rows_after_dropping_null = df_new.dropna(axis=0).shape[0]
rows_before_dropping_null = df_new.shape[0]

perc_info_loss = (rows_before_dropping_null - rows_after_dropping_null)*100/rows_before_dropping_null
print("Доля нулевых строк в датасете: {:.2f}%".format(perc_info_loss))
# Out:
# Доля нулевых строк в датасете: 1.59%

# %% [markdown]
# ## Удалим пропуски из датасета, т.к. это даст незначительную потерю информации 1,59%, но можно восстановить данные, если перевести данные в часы и минуты

# %%
df_new.dropna(axis=0,inplace=True)

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5726549 entries, 0 to 5818484
# Data columns (total 24 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   DAY_OF_WEEK          int64
#  1   AIRLINE_x            object
#  2   ORIGIN_AIRPORT       object
#  3   DESTINATION_AIRPORT  object
#  4   SCHEDULED_DEPARTURE  int64
#  5   DEPARTURE_TIME       float64
#  6   DEPARTURE_DELAY_x    float64
#  7   TAXI_OUT_x           float64
#  8   WHEELS_OFF           float64
#  9   SCHEDULED_TIME       float64
#  10  DISTANCE             int64
#  11  WHEELS_ON            float64
#  12  TAXI_IN              float64
#  13  SCHEDULED_ARRIVAL    int64
#  14  ARRIVAL_TIME         float64
#  15  ARRIVAL_DELAY_x      float64
#  16  WEATHER_DELAY        float64
#  17  IATA_CODE_x          object
#  18  AIRLINE_y            object
#  19  IATA_CODE_y          object
#  20  AIRPORT              object
#  21  CITY                 object
#  22  STATE                object
#  23  DATE                 datetime64[ns]
# dtypes: datetime64[ns](1), float64(10), int64(4), object(9)
# memory usage: 1.1+ GB

# %%
# AIRLINE_x = IATA_CODE_x - удалим 1 колонку
df_new.drop('IATA_CODE_x', axis = 1, inplace = True)

# %% [markdown]
# ## Преобразуем текстовые данные

# %%
df_new1 = pd.get_dummies(df_new, columns=['AIRLINE_x','ORIGIN_AIRPORT','DESTINATION_AIRPORT','AIRLINE_y'])

# %%
df_new2 = pd.get_dummies(df_new1, columns=['IATA_CODE_y','AIRPORT','CITY','STATE'])

# %%
df_new2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5726549 entries, 0 to 5818484
# Columns: 1698 entries, DAY_OF_WEEK to STATE_WY
# dtypes: datetime64[ns](1), float64(10), int64(4), uint8(1683)
# memory usage: 9.7 GB

# %% [markdown]
# ## Здесь при проверке на монотонность тоже зависает (я так поняла из-за индекса) и ядро тоже иногда не выдерживает (умирает)

# %%
df_new2.set_index('DATE', inplace=True)
df_new2.sort_index(inplace=True)
print('Монотонность - ',df_new2.index.is_monotonic)
# Out:
# Монотонность -  True

# %%
df_new2.reset_index()

# %%
# переводим float в int (как выяснилось - это не помогло)
df_new2['DEPARTURE_TIME'] = df_new2['DEPARTURE_TIME'].round(0).astype('int')
df_new2['DEPARTURE_DELAY_x'] = df_new2['DEPARTURE_DELAY_x'].round(0).astype('int')
df_new2['TAXI_OUT_x'] = df_new2['TAXI_OUT_x'].round(0).astype('int')
df_new2['WHEELS_OFF'] = df_new2['WHEELS_OFF'].round(0).astype('int')
df_new2['SCHEDULED_TIME'] = df_new2['SCHEDULED_TIME'].round(0).astype('int')
df_new2['TAXI_IN'] = df_new2['TAXI_IN'].round(0).astype('int')
df_new2['WHEELS_ON'] = df_new2['WHEELS_ON'].round(0).astype('int')
df_new2['ARRIVAL_TIME'] = df_new2['ARRIVAL_TIME'].round(0).astype('int')
df_new2['ARRIVAL_DELAY_x'] = df_new2['ARRIVAL_DELAY_x'].round(0).astype('int')
df_new2['WEATHER_DELAY'] = df_new2['WEATHER_DELAY'].round(0).astype('int')

# %%
df_new2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5726549 entries, 0 to 5818484
# Columns: 1698 entries, DAY_OF_WEEK to STATE_WY
# dtypes: datetime64[ns](1), float64(10), int64(4), uint8(1683)
# memory usage: 9.7 GB

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
X_train, X_test, y_train, y_test = train_test_split(df_new2.drop('ARRIVAL_DELAY_x',axis=1), df_new2['ARRIVAL_DELAY_x'], shuffle=False, test_size=0.25)

# %%
clf = RandomForestRegressor()
model = clf.fit(X_train, y_train)
pred = model.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/bm/glmrb3ps3c14r341qn4q03hc0000gn/T/ipykernel_760/2109972256.py in <module>
#       1 clf = RandomForestRegressor()
# ----> 2 model = clf.fit(X_train, y_train)
#       3 pred = model.predict(X_test)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py in fit(self, X, y, sample_weight)
#     302                 "sparse multilabel-indicator for y is not supported."
#     303             )
# --> 304         X, y = self._validate_data(X, y, multi_output=True,
#     305                                    accept_sparse="csc", dtype=DTYPE)
#     306         if sample_weight is not None:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     431                 y = check_array(y, **check_y_params)
#     432             else:
# --> 433                 X, y = check_X_y(X, y, **check_params)
#     434             out = X, y
#     435
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#     869         raise ValueError("y cannot be None")
#     870
# --> 871     X = check_array(X, accept_sparse=accept_sparse,
#     872                     accept_large_sparse=accept_large_sparse,
#     873                     dtype=dtype, order=order, copy=copy,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     595
#     596         if all(isinstance(dtype, np.dtype) for dtype in dtypes_orig):
# --> 597             dtype_orig = np.result_type(*dtypes_orig)
#     598
#     599     if dtype_numeric:
#
# <__array_function__ internals> in result_type(*args, **kwargs)
#
# TypeError: The DTypes <class 'numpy.dtype[datetime64]'> and <class 'numpy.dtype[int64]'> do not have a common DType. For example they cannot be stored in a single array unless the dtype is `object`.

# %%
print('Ошибка RMSE=',mean_squared_error(y_test,pred,squared=False))

# %% [markdown]
# ### Ну вот выходит вот такая ошибка в predict и на этом я застряла, ниже просто пыталась установить prophet (не получается)

# %%
from prophet import Prophet
m = Prophet()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/bm/glmrb3ps3c14r341qn4q03hc0000gn/T/ipykernel_1479/1238099699.py in <module>
# ----> 1 from prophet import Prophet
#       2 m = Prophet()
#
# ModuleNotFoundError: No module named 'prophet'

# %%
conda install -c conda-forge prophet
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: /
# Found conflicts! Looking for incompatible packages.
# This can take several minutes.  Press CTRL-C to abort.
#                                                                                                                                      \failed
#
# UnsatisfiableError: The following specifications were found
# to be incompatible with the existing python installation in your environment:
#
# Specifications:
#
#   - alabaster -> python[version='2.7.*|3.5.*|3.6.*|>=2.7,<2.8.0a0|>=3.5,<3.6.0a0|>=3.6,<3.7.0a0|3.4.*|>=3.7,<3.8.0a0']
#   - anaconda==2021.11 -> python[version='3.7.11|3.8.12|3.9.7',build='h88f2d9e_0|h88f2d9e_1']
#   - appdirs -> python[version='2.7.*|3.5.*|3.6.*|3.4.*|>=3.5,<3.6.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=2.7,<2.8.0a0']
#   - argon2-cffi -> python[version='2.7.*|3.5.*|3.6.*|3.6.12|3.6.12|3.7.10|3.7.10|3.7.12|3.7.9|3.6.9|3.6.9|3.6.9|3.6.9|>=3.5,<3.6.0a0|3.4.*|3.7.*|3.9.*|3.8.*|3.10.*',build='3_73_pypy|5_73_pypy|5_73_pypy|0_73_pypy|1_73_pypy|0_73_pypy|4_73_pypy|2_73_pypy|1_73_pypy|0_73_pypy']
#   - asn1crypto -> python[version='2.7.*|3.5.*|3.6.*|>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.8,<3.9.0a0|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0|>=3.10,<3.11.0a0']
#   - asn1crypto -> python[version='3.7.*|3.8.*']
#   - atomicwrites -> python[version='2.7.*|3.5.*|3.6.*|>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.5,<3.6.0a0|>=3.7,<3.8.0a0']
#   - backcall -> python[version='>=2.7,<2.8.0a0|>=3.5,<3.6.0a0|>=3.7,<3.8.0a0|>=3.8,<3.9.0a0|>=3.6,<3.7.0a0']
#   - backports -> python[version='2.7.*|3.5.*|3.6.*|>=3.5,<3.6.0a0|>=2.7,<2.8.0a0|>=3.7,<3.8.0a0|>=3.6,<3.7.0a0']
#   - backports.shutil_get_terminal_size -> python[version='2.7.*|3.4.*|3.5.*|3.6.*|>=3.8,<3.9.0a0|>=3.5,<3.6.0a0|>=2.7,<2.8.0a0|>=3.7,<3.8.0a0|>=3.6,<3.7.0a0']
#   - binaryornot -> python[version='2.7.*|3.5.*|3.6.*|3.4.*']
#   - bkcharts -> python[version='3.4.*|>=3.7.1,<3.8.0a0']
#   - brotlipy -> python[version='3.10.*|3.4.*|3.6.12|3.6.12|3.7.10|3.7.10|3.7.12|3.7.9|3.6.9|3.6.9|3.6.9|3.6.9|3.7.*|3.8.*|3.9.*',build='3_73_pypy|5_73_pypy|5_73_pypy|0_73_pypy|1_73_pypy|0_73_pypy|4_73_pypy|2_73_pypy|1_73_pypy|0_73_pypy']
#   - cached-property -> python[version='2.7.*|3.5.*|3.6.*|>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.5,<3.6.0a0|>=3.8,<3.9.0a0|>=3.7,<3.8.0a0']
#   - cffi -> python[version='2.7.*|3.5.*|3.6.*|3.6.12|3.6.12|3.7.10|3.7.10|3.7.12|>=3.10,<3.11.0a0|>=3.7,<3.8.0a0|>=3.8,<3.9.0a0|>=3.9,<3.10.0a0|>=3.6,<3.7.0a0|3.7.9|3.6.9|3.6.9|3.6.9|>=2.7,<2.8.0a0|3.6.9|>=3.5,<3.6.0a0|3.4.*',build='3_73_pypy|5_73_pypy|5_73_pypy|0_73_pypy|1_73_pypy|0_73_pypy|4_73_pypy|2_73_pypy|1_73_pypy|0_73_pypy']
#   - colorama -> python[version='2.7.*|3.5.*|3.6.*|3.4.*|>=3.6,<3.7.0a0|>=2.7,<2.8.0a0|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0']
#   - conda-env -> python[version='2.7.*|3.4.*|3.5.*']
#   - cryptography -> python[version='3.10.*|3.6.12|3.6.12|3.7.10|3.7.10|3.7.12|3.7.9|3.6.9|3.6.9|3.6.9|3.6.9|3.8.*|3.7.*|3.9.*|3.4.*|>=3.6|>=3.5|<=3.3',build='3_73_pypy|5_73_pypy|5_73_pypy|0_73_pypy|1_73_pypy|0_73_pypy|4_73_pypy|2_73_pypy|1_73_pypy|0_73_pypy']
#   - diff-match-patch -> python[version='2.7.*|3.4.*|3.5.*|3.6.*']
#   - get_terminal_size -> python[version='2.7.*|3.4.*|3.5.*|3.6.*|>=3.8,<3.9.0a0|>=3.5,<3.6.0a0|>=2.7,<2.8.0a0|>=3.7,<3.8.0a0|>=3.6,<3.7.0a0']
#   - gevent -> python[version='3.10.*|3.6.12|3.6.12|3.7.10|3.7.10|3.7.12|3.7.9|3.6.9|3.6.9|3.6.9|3.6.9|3.4.*|3.7.*|3.9.*|3.8.*',build='3_73_pypy|5_73_pypy|5_73_pypy|0_73_pypy|1_73_pypy|0_73_pypy|4_73_pypy|2_73_pypy|1_73_pypy|0_73_pypy']
#   - glob2 -> python[version='2.7.*|3.4.*|3.5.*|3.6.*|>=2.7,<2.8.0a0|>=3.7,<3.8.0a0|>=3.6,<3.7.0a0|>=3.5,<3.6.0a0']
#   - heapdict -> python[version='2.7.*|3.4.*|3.5.*|3.6.*|>=2.7,<2.8.0a0|>=3.5,<3.6.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=3.8,<3.9.0a0']
#   - html5lib -> python[version='2.7.*|3.5.*|3.6.*|>=3.5,<3.6.0a0|>=2.7,<2.8.0a0|>=3.7,<3.8.0a0|>=3.6,<3.7.0a0']
#   - importlib_metadata -> python[version='>=2.7,<2.8.0a0|>=3.8,<3.9.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0']
#   - intervaltree -> python[version='2.7.*|3.5.*|3.6.*']
#   - ipython_genutils -> python[version='2.7.*|3.4.*|3.5.*|3.6.*|>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.8,<3.9.0a0|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0']
#   - jdcal -> python[version='2.7.*|3.5.*|3.6.*|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0|>=2.7,<2.8.0a0|>=3.6,<3.7.0a0']
#   - jinja2-time -> python[version='2.7.*|3.5.*|3.6.*|3.4.*']
#   - olefile -> python[version='2.7.*|3.5.*|3.6.*|3.4.*|>=3.5,<3.6.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=2.7,<2.8.0a0']
#   - patsy -> python[version='>=3.10,<3.11.0a0']
#   - pexpect -> python[version='2.7.*|3.5.*|3.6.*|>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=3.8,<3.9.0a0|>=3.5,<3.6.0a0|3.4.*']
#   - pexpect -> python[version='3.7.*|3.8.*']
#   - poyo -> python[version='2.7.*|3.5.*|3.6.*|3.4.*']
#   - ptyprocess -> python[version='2.7.*|3.5.*|3.6.*|>=2.7,<2.8.0a0|>=3.5,<3.6.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|3.4.*|>=3.8,<3.9.0a0']
#   - pyls-spyder -> python[version='2.7.*|3.5.*|3.6.*|>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=3.8,<3.9.0a0|>=3.5,<3.6.0a0']
#   - singledispatch -> python[version='2.7.*|3.4.*|3.5.*|3.6.*|>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=3.8,<3.9.0a0|>=3.5,<3.6.0a0']
#   - sortedcollections -> python[version='>=3.8,<3.9.0a0']
#   - text-unidecode -> python[version='>=2.7,<2.8.0a0|>=3.5,<3.6.0a0|>=3.7,<3.8.0a0|>=3.6,<3.7.0a0']
#   - three-merge -> python[version='2.7.*|3.4.*|3.5.*|3.6.*']
#   - wcwidth -> python[version='2.7.*|3.4.*|3.5.*|3.6.*|>=3.6,<3.7.0a0|>=2.7,<2.8.0a0|>=3.8,<3.9.0a0|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0']
#   - whichcraft -> python[version='2.7.*|3.5.*|3.6.*|3.4.*']
#   - xmltodict -> python[version='2.7.*|3.5.*|3.6.*|3.4.*|>=3.5,<3.6.0a0|>=3.6,<3.7.0a0|>=2.7,<2.8.0a0|>=3.7,<3.8.0a0']
#   - zict -> python[version='2.7.*|3.5.*|3.6.*|3.4.*|>=3.7,<3.8.0a0|>=3.6,<3.7.0a0|>=2.7,<2.8.0a0|>=3.5,<3.6.0a0']
#   - zict -> python[version='>=3.8,<3.9.0a0']
#   - zope.event -> python[version='2.7.*|3.5.*|3.6.*|>=3.5,<3.6.0a0|3.4.*']
#
# Your python: python=3.9
#
# If python is on the left-most side of the chain, that's the version you've asked for.
# When python appears to the right, that indicates that the thing on the left is somehow
# not available for the python version you are constrained to. Note that conda will not
# change your python version to a different minor version unless you explicitly specify
# that.
#
# The following specifications were found to be incompatible with each other:
#
# Output in format: Requested package -> Available versions
#
# Package yaml conflicts for:
# conda-repo-cli -> pyyaml[version='>=3.12'] -> yaml[version='>=0.1.7,<0.2.0a0|>=0.2.2,<0.3.0a0|>=0.2.5,<0.3.0a0']
# anaconda-navigator -> pyyaml[version='>=5.1'] -> yaml[version='>=0.1.7,<0.2.0a0|>=0.2.2,<0.3.0a0|>=0.2.5,<0.3.0a0']
# ruamel_yaml -> yaml[version='>=0.1.7,<0.2.0a0|>=0.2.2,<0.3.0a0|>=0.2.5,<0.3.0a0']
# distributed -> pyyaml -> yaml[version='>=0.1.7,<0.2.0a0|>=0.2.2,<0.3.0a0|>=0.2.5,<0.3.0a0']
# dask-core -> pyyaml[version='>=5.3.1'] -> yaml[version='>=0.1.7,<0.2.0a0|>=0.2.2,<0.3.0a0|>=0.2.5,<0.3.0a0']
# anaconda-client -> pyyaml[version='>=3.12'] -> yaml[version='>=0.1.7,<0.2.0a0|>=0.2.2,<0.3.0a0|>=0.2.5,<0.3.0a0']
# anaconda==2021.11 -> pyyaml==6.0=py37hca72f7f_1 -> yaml[version='>=0.2.5,<0.3.0a0']
# pyyaml -> yaml[version='>=0.1.7,<0.2.0a0|>=0.2.2,<0.3.0a0|>=0.2.5,<0.3.0a0']
# bokeh -> pyyaml[version='>=3.10'] -> yaml[version='>=0.1.7,<0.2.0a0|>=0.2.2,<0.3.0a0|>=0.2.5,<0.3.0a0']
# conda-build -> pyyaml -> yaml[version='>=0.1.7,<0.2.0a0|>=0.2.2,<0.3.0a0|>=0.2.5,<0.3.0a0']
# astropy -> pyyaml[version='>=3.13'] -> yaml[version='>=0.1.7,<0.2.0a0|>=0.2.2,<0.3.0a0|>=0.2.5,<0.3.0a0']
# anaconda==2021.11 -> yaml==0.2.5=haf1e3a3_0
# anaconda-project -> ruamel_yaml -> yaml[version='>=0.1.7,<0.2.0a0|>=0.2.2,<0.3.0a0|>=0.2.5,<0.3.0a0']
# conda[version='>=4.10.3'] -> ruamel_yaml[version='>=0.11.14,<0.16'] -> yaml[version='>=0.1.7,<0.2.0a0|>=0.2.2,<0.3.0a0|>=0.2.5,<0.3.0a0']
# watchdog -> pyyaml[version='>=3.10'] -> yaml[version='>=0.1.7,<0.2.0a0|>=0.2.2,<0.3.0a0|>=0.2.5,<0.3.0a0']
# conda-verify -> pyyaml -> yaml[version='>=0.1.7,<0.2.0a0|>=0.2.2,<0.3.0a0|>=0.2.5,<0.3.0a0']
#
# Package xz conflicts for:
# setuptools -> python[version='>=3.8,<3.9.0a0'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# numexpr -> python[version='>=3.7,<3.8.0a0'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# nbconvert -> python[version='>=3.9,<3.10.0a0'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# tifffile -> imagecodecs[version='>=2021.7.30'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# openjpeg -> libtiff[version='>=4.2.0,<5.0a0'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# chardet -> python[version='>=3.7,<3.8.0a0'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# binaryornot -> python -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# boto -> python -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# pluggy -> python[version='>=3.10,<3.11.0a0'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# entrypoints -> python[version='>=3.6'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# pexpect -> python -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# mkl_fft -> python[version='>=3.9,<3.10.0a0'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# sphinxcontrib-jsmath -> python[version='>=3.5'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# requests -> python[version='>=3.6'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# path.py -> python[version='>=3.5'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# wurlitzer -> python[version='>=3.9,<3.10.0a0'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# conda[version='>=4.10.3'] -> python[version='>=3.7,<3.8.0a0'] -> xz[version='5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# werkzeug -> python[version='>=3.6'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# babel -> python -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# scikit-learn-intelex -> python[version='>=3.8,<3.9.0a0'] -> xz[version='5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# lazy-object-proxy -> python[version='>=3.10,<3.11.0a0'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# ipython_genutils -> python -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# prophet -> python[version='>=3.7,<3.8.0a0'] -> xz[version='5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# py -> python[version='>=2.7'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# mkl-service -> python[version='>=3.10,<3.11.0a0'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# jupyter_core -> python[version='>=3.9,<3.10.0a0'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# lxml -> libxml2[version='>=2.9.12,<2.10.0a0'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# asn1crypto -> python -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# pytables -> python[version='>=3.9,<3.10.0a0'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# jedi -> python[version='>=3.7,<3.8.0a0'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# widgetsnbextension -> python[version='>=3.10,<3.11.0a0'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# webencodings -> python -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# pkginfo -> python[version='>=3.6'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# numba -> python[version='>=3.10,<3.11.0a0'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# docutils -> python[version='>=3.8,<3.9.0a0'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# dask-core -> python[version='>=3.7'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# attrs -> python[version='>=2.7,!=3.0.*,!=3.1.*,!=3.2.*,!=3.3.*,!=3.4.*'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# backports.tempfile -> python -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# greenlet -> python[version='>=3.10,<3.11.0a0'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# qtconsole -> python[version='>=3.6'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# toml -> python[version='>=2.7'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# sip -> python[version='>=3.8,<3.9.0a0'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# typed-ast -> python[version='>=3.10,<3.11.0a0'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# conda-repo-cli -> python -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# sortedcollections -> python[version='>=3.6'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# sphinxcontrib -> python[version='>=3.10,<3.11.0a0'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# jupyter_client -> python[version='>=3.6.1'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# nbclassic -> python[version='>=3.6'] -> xz[version='5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# conda-token -> python -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# pycosat -> python[version='>=3.8,<3.9.0a0'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# jsonschema -> python[version='>=3.7'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# bitarray -> python[version='>=3.8,<3.9.0a0'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# pycparser -> python[version='2.7.*|>=3.4'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# partd -> python[version='>=3.5'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# pylint -> python[version='>=3.6.2,<4'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# multipledispatch -> python -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# cffi -> python[version='>=3.7,<3.8.0a0'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# unicodecsv -> python -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# pyflakes -> python[version='2.7.*|>=3.5'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# pydocstyle -> python[version='>=3.6'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# pyparsing -> python[version='>=3.6'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# numpy-base -> python[version='>=3.10,<3.11.0a0'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# bkcharts -> python=3.6 -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# matplotlib-inline -> python[version='>=3.6'] -> xz[version='5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# tqdm -> python[version='>=2.7'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# llvmlite -> python[version='>=3.8,<3.9.0a0'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# defusedxml -> python[version='>=3.6'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# pyopenssl -> python[version='>=2.7'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# rope -> python[version='>=3.6'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# nbformat -> python[version='>=3.5'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# terminado -> pypy3.7[version='>=7.3.7'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# libxml2 -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# jupyterlab_widgets -> python[version='>=3.6'] -> xz[version='5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# anaconda==2021.11 -> imagecodecs==2021.8.26=py37ha952a84_0 -> xz[version='>=5.2.5,<6.0a0']
# glob2 -> python -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# joblib -> python[version='>=3.6'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# astropy -> python[version='>=3.10,<3.11.0a0'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# sphinx -> python[version='>=3.6'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# cloudpickle -> python[version='>=3.6'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# libwebp -> libtiff[version='>=4.3.0,<5.0a0'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# json5 -> python -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# pyqt -> python[version='>=3.9,<3.10.0a0'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# nbclient -> python[version='>=3.7'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# arrow -> python[version='>=3.6'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# ujson -> python[version='>=3.9,<3.10.0a0'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# wrapt -> python[version='>=3.10,<3.11.0a0'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# _ipyw_jlab_nb_ext_conf -> python[version='>=3.10,<3.11.0a0'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# daal4py -> pypy3.7[version='>=7.3.7'] -> xz[version='5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# pandas -> python[version='>=3.10,<3.11.0a0'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# prompt-toolkit -> python[version='>=3.6'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# pytest -> python[version='>=3.7,<3.8.0a0'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# atomicwrites -> python -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# urllib3 -> python[version='<4.0'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# python-dateutil -> python[version='>=3.6'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# text-unidecode -> python -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# testpath -> python[version='>=3.5'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# pyodbc -> python[version='>=3.7,<3.8.0a0'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# filelock -> python[version='>=3.7'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# mock -> python[version='>=3.9,<3.10.0a0'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# python-slugify -> python[version='>=3.6'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# packaging -> python[version='>=3.6'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# threadpoolctl -> python[version='>=3.6'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# appscript -> python[version='>=3.10,<3.11.0a0'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# argh -> python -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# keyring -> pypy3.7[version='>=7.3.7'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# pysocks -> python[version='>=3.10,<3.11.0a0'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# pathlib2 -> python[version='>=3.9,<3.10.0a0'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# pyyaml -> python[version='>=3.7,<3.8.0a0'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# xmltodict -> python -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# snowballstemmer -> python[version='>=2'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# libxslt -> libxml2[version='>=2.9.12,<2.10.0a0'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# ruamel_yaml -> pypy3.7[version='>=7.3.7'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# sphinxcontrib-qthelp -> python[version='>=3.5'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# pathspec -> python[version='>=2.7,!=3.0.*,!=3.1.*,!=3.2.*,!=3.3.*,!=3.4.*'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# path -> python[version='>=3.7,<3.8.0a0'] -> xz[version='5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# notebook -> python[version='>=3.7'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# pillow -> libtiff[version='>=4.3.0,<5.0a0'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# pep8 -> python -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# et_xmlfile -> python -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# whichcraft -> python -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# markupsafe -> python[version='>=3.10,<3.11.0a0'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# distributed -> python[version='>=3.8,<3.9.0a0'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# gmpy2 -> python[version='>=3.9,<3.10.0a0'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# conda-verify -> pypy3.7[version='>=7.3.7'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# anaconda-client -> python[version='>=3.6'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# singledispatch -> python -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# navigator-updater -> python[version='>=3.9,<3.10.0a0'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# pyrsistent -> python[version='>=3.10,<3.11.0a0'] -> xz[version='5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# python.app -> python[version='>=3.8,<3.9.0a0'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# async_generator -> python[version='>2.7'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# conda-env -> python=3.5 -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# backports.shutil_get_terminal_size -> python -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# h5py -> python[version='>=3.10,<3.11.0a0'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# zope -> python[version='>=3.10,<3.11.0a0'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# pycurl -> python[version='>=3.8,<3.9.0a0'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# openpyxl -> python[version='>=3.6'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# importlib_metadata -> python[version='>=3.8,<3.9.0a0'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# regex -> pypy3.7[version='>=7.3.7'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# pytz -> python[version='>=3'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# xlrd -> python[version='>=3.6'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# contextlib2 -> python[version='>=3.6'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# pycodestyle -> python[version='2.7.*|>=3.5'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# libarchive -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# numpydoc -> python[version='>=3.5'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# kiwisolver -> pypy3.7[version='>=7.3.7'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# simplegeneric -> python -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# debugpy -> pypy3.7[version='>=7.3.7'] -> xz[version='5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# future -> python[version='>=3.8,<3.9.0a0'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# pygments -> python[version='>=3.6'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# cycler -> python[version='>=3.6'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# matplotlib -> pypy3.7[version='>=7.3.7'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# three-merge -> python -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# msgpack-python -> python[version='>=3.7,<3.8.0a0'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# seaborn -> python[version='>=3.6'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# python-libarchive-c -> libarchive -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# patsy -> python[version='>=3.6'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# jupyterlab_server -> python[version='>=3.6'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# html5lib -> python -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# jinja2-time -> python -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# watchdog -> python[version='>=3.10,<3.11.0a0'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# cryptography -> pypy3.7[version='>=7.3.7'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# locket -> python -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# zict -> python -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# zope.interface -> pypy3.7[version='>=7.3.7'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# olefile -> python -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# qtpy -> python[version='>=3.6'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# anaconda-navigator -> python[version='>=3.7,<3.8.0a0'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# pywavelets -> pypy3.7[version='>=7.3.7'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# jdcal -> python -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# mistune -> python[version='>=2.7'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# tornado -> python[version='>=3.8,<3.9.0a0'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# autopep8 -> python[version='>=3.6'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# xlsxwriter -> python[version='>=3.4'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# lcms2 -> libtiff[version='>=4.2.0,<5.0a0'] -> xz[version='>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0']
# sphinxcontrib-devhelp -> python[version='>=3.5'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# numpy -> python[version='>=3.10,<3.11.0a0'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# idna -> python[version='>=3.6'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# python-lsp-server -> python[version='>=3.6'] -> xz[version='5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# yapf -> python[version='>=2.7'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# sphinxcontrib-htmlhelp -> python[version='>=3.5'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# backports -> python -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# scikit-image -> pypy3.7[version='>=7.3.7'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# heapdict -> python -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# colorama -> python -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# spyder-kernels -> python[version='>=3.7,<3.8.0a0'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# textdistance -> python[version='>=2.7'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# scikit-learn -> pypy3.7[version='>=7.3.7'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# pyerfa -> python[version='>=3.10,<3.11.0a0'] -> xz[version='5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# brotlipy -> python[version='>=3.7,<3.8.0a0'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# cookiecutter -> python[version='>=3.6'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# decorator -> python[version='>=3.5'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# imagecodecs -> python[version='>=3.7,<3.8.0a0'] -> xz[version='5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# fonttools -> python[version='>=3.10,<3.11.0a0'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# clyent -> python -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# mccabe -> python[version='>=3.6'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# qdarkstyle -> python[version='>=3.6'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# sphinxcontrib-applehelp -> python[version='>=3.5'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# statsmodels -> pypy3.7[version='>=7.3.7'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# spyder -> python[version='>=3.9,<3.10.0a0'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# unidecode -> python[version='>=3.5'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# zipp -> python[version='>=3.6'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# isort -> python[version='>=3.6,<4.0'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# sniffio -> python[version='>=3.10,<3.11.0a0'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# scipy -> pypy3.7[version='>=7.3.7'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# applaunchservices -> python -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# libxslt -> xz[version='>=5.2.5,<6.0a0']
# jupyter_server -> python[version='>=3.7'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# imagesize -> python[version='>=3.4'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# ipython -> python[version='>=3.10,<3.11.0a0'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# bokeh -> python[version='>=3.7,<3.8.0a0'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# matplotlib-base -> pypy3.7[version='>=7.3.7'] -> xz[version='5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# traitlets -> python[version='>=3.7'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# nest-asyncio -> python[version='>=3.5'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# bottleneck -> python[version='>=3.9,<3.10.0a0'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# diff-match-patch -> python -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# qtawesome -> python[version='>=3.6'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# alabaster -> python -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# backports.functools_lru_cache -> python[version='>=3.6'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# imageio -> python[version='>=3'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# astroid -> python[version='>=3.9,<3.10.0a0'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# pyjwt -> python[version='>=3.6'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# python-lsp-black -> python[version='>=3.6'] -> xz[version='5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# conda-content-trust -> python[version='>=3.5'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# typing_extensions -> python[version='>=3.6'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# dataclasses -> python[version='>=3.7'] -> xz[version='5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# itsdangerous -> python[version='>=3.6'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# charset-normalizer -> python[version='>=3.6'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# more-itertools -> python[version='>=3.4'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# backcall -> python -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# wcwidth -> python -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# ipywidgets -> python[version='>=3.3'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# xlwt -> python -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# appdirs -> python -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# click -> python[version='>=3.7,<3.8.0a0'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# sympy -> python[version='>=3.10,<3.11.0a0'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# anaconda-project -> python[version='>=2.7'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# flake8 -> python[version='>=3.6'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# python-lsp-jsonrpc -> python[version='>=3.6'] -> xz[version='5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# dask -> python[version='>=3.7'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# fsspec -> python[version='>=3.6'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# cached-property -> python -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# jinja2 -> python[version='>=3.6'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# qstylizer -> python[version='>=3.6'] -> xz[version='5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# anaconda==2021.11 -> xz==5.2.5=h1de35cc_0
# tbb4py -> python[version='>=3.10,<3.11.0a0'] -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# munkres -> python -> xz[version='5.0.*|5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0|>=5.2.4,<6.0a0|>=5.2.3,<6.0a0']
# ...
# dask-core -> fsspec[version='>=0.6.0']
# scikit-image -> dask-core[version='>=1.0.0,!=2.17.0'] -> fsspec[version='>=0.4.0|>=0.5.1|>=0.6.0']
# dask -> fsspec[version='>=0.4.0|>=0.5.1|>=0.6.0']
# anaconda==2021.11 -> fsspec==2021.8.1=pyhd3eb1b0_0
# distributed -> dask-core=2022.1.0 -> fsspec[version='2021.04.0|2021.05.0|2021.06.0|2021.06.1|2021.10.0|2021.10.1|2021.11.0|2021.11.1|2022.1.0|>=0.4.0|>=0.5.1|>=0.6.0|2021.9.0|2021.8.1|2021.7.0|>=0.9.0|>=0.8.0|2021.7.0.*|2021.6.0.*']
#
# Package mpfr conflicts for:
# anaconda==2021.11 -> gmpy2==2.0.8=py37h6ef4df4_2 -> mpfr[version='>=4.0.1,<5.0a0|>=4.0.2,<5.0a0']
# mpc -> mpfr[version='3.*|4.*|>=4.0.1,<5.0a0|>=4.0.2,<5.0a0|>=4.1.0,<5.0a0']
# mpmath -> gmpy2 -> mpfr[version='3.*|>=4.0.1,<5.0a0|>=4.0.2,<5.0a0|>=4.1.0,<5.0a0']
# sympy -> gmpy2[version='>=2.0.8'] -> mpfr[version='3.*|>=4.0.1,<5.0a0|>=4.0.2,<5.0a0|>=4.1.0,<5.0a0']
# scipy -> libgcc -> mpfr[version='>=2.4.0']
# gmpy2 -> mpfr[version='3.*|>=4.0.1,<5.0a0|>=4.0.2,<5.0a0|>=4.1.0,<5.0a0']
# anaconda==2021.11 -> mpfr==4.0.2=h9066e36_1
# gmpy2 -> mpc[version='>=1.1.0,<2.0a0'] -> mpfr=4
# giflib -> libgcc -> mpfr[version='>=2.4.0']
#
# Package sphinxcontrib conflicts for:
# anaconda==2021.11 -> sphinxcontrib==1.0[build='py38_1|py37_1|py39hecd8cb5_1']
# sphinxcontrib-websupport -> sphinxcontrib
# anaconda==2021.11 -> sphinxcontrib-websupport==1.2.4=py_0 -> sphinxcontrib
# sphinx -> sphinxcontrib-websupport -> sphinxcontrib
#
# Package selectors2 conflicts for:
# spyder-kernels -> wurlitzer[version='>=1.0.3'] -> selectors2
# wurlitzer -> selectors2
#
# Package msgpack-python conflicts for:
# anaconda==2021.11 -> distributed==2021.10.0=py37hecd8cb5_0 -> msgpack-python[version='>=0.6.0']
# distributed -> msgpack-python[version='<1.0.0|>=0.6.0']
# dask -> distributed=2022.1.0 -> msgpack-python[version='<1.0.0|>=0.6.0']
# anaconda==2021.11 -> msgpack-python==1.0.2[build='py39hf7b0b51_1|py37hf7b0b51_1|py38hf7b0b51_1']
#
# Package patsy conflicts for:
# seaborn -> patsy
# anaconda==2021.11 -> patsy==0.5.2[build='py37hecd8cb5_0|py38hecd8cb5_0|py39hecd8cb5_0']
# statsmodels -> patsy[version='>=0.4.0|>=0.5.1|>=0.5.2']
# anaconda==2021.11 -> statsmodels==0.12.2=py37h9ed2024_0 -> patsy[version='>=0.5.1']
# seaborn -> statsmodels[version='>=0.8.0'] -> patsy[version='>=0.4.0|>=0.5.1|>=0.5.2']
#
# Package diff-match-patch conflicts for:
# spyder -> diff-match-patch[version='>=20181111']
# three-merge -> diff-match-patch
# anaconda==2021.11 -> diff-match-patch==20200713=pyhd3eb1b0_0
# anaconda==2021.11 -> spyder==5.1.5=py37hecd8cb5_1 -> diff-match-patch[version='>=20181111']
#
# Package helpdev conflicts for:
# qdarkstyle -> helpdev[version='>=0.6.10']
# spyder -> qdarkstyle[version='>=2.8,<3.0'] -> helpdev[version='>=0.6.10']
#
# Package pbr conflicts for:
# pytables -> mock -> pbr[version='>=1.3']
# mock -> pbr[version='>=1.3']
#
# Package conda-package-handling conflicts for:
# conda[version='>=4.10.3'] -> conda-package-handling[version='>=1.3.0']
# conda-build -> conda-package-handling[version='>=1.1|>=1.3']
# conda-verify -> conda-package-handling[version='>=1.0.4|>=1.1']
# conda-build -> conda[version='>=4.5'] -> conda-package-handling[version='>=1.0.4|>=1.3.0']
# conda-token -> conda[version='>=4.3'] -> conda-package-handling[version='>=1.3.0']
#
# Package wurlitzer conflicts for:
# spyder-kernels -> wurlitzer[version='>=1.0.3']
# anaconda==2021.11 -> spyder-kernels==2.1.3=py37hecd8cb5_0 -> wurlitzer[version='>=1.0.3']
# anaconda==2021.11 -> wurlitzer==2.1.1[build='py37hecd8cb5_0|py38hecd8cb5_0|py39hecd8cb5_0']
# spyder -> spyder-kernels[version='>=2.2.1,<2.3.0'] -> wurlitzer[version='>=1.0.3']
#
# Package zope.event conflicts for:
# anaconda==2021.11 -> gevent==21.8.0=py37h9ed2024_1 -> zope.event
# gevent -> zope.event
# anaconda==2021.11 -> zope.event==4.5.0[build='py39hecd8cb5_0|py38_0|py37_0']
#
# Package libedit conflicts for:
# python=3.9 -> sqlite[version='>=3.33.0,<4.0a0'] -> libedit[version='>=3.1.20191231,<3.2.0a0']
# qt -> sqlite[version='>=3.33.0,<4.0a0'] -> libedit[version='>=3.1.20170329,<3.2.0a0|>=3.1.20181209,<3.2.0a0|>=3.1.20191231,<3.2.0a0']
# sqlite -> libedit[version='>=3.1.20170329,<3.2.0a0|>=3.1.20181209,<3.2.0a0|>=3.1.20191231,<3.2.0a0']
# curl -> krb5[version='>=1.19.2,<1.20.0a0'] -> libedit[version='>=3.1.20170329,<3.2.0a0|>=3.1.20170329,<4.0a0|>=3.1.20191231,<3.2.0a0|>=3.1.20191231,<4.0a0|>=3.1.20210216,<3.2.0a0|>=3.1.20210216,<4.0a0|>=3.1.20181209,<3.2.0a0|>=3.1.20181209,<4.0a0']
# anaconda==2021.11 -> libedit==3.1.20210910=hca72f7f_0
# pyodbc -> unixodbc[version='>=2.3.9,<2.4.0a0'] -> libedit[version='>=3.1.20170329,<3.2.0a0|>=3.1.20191231,<3.2.0a0']
# unixodbc -> libedit[version='>=3.1.20170329,<3.2.0a0|>=3.1.20191231,<3.2.0a0']
# anaconda==2021.11 -> krb5==1.19.2=hcd88c3b_0 -> libedit[version='>=3.1.20191231,<3.2.0a0|>=3.1.20210216,<3.2.0a0|>=3.1.20210216,<4.0a0']
# krb5 -> libedit[version='>=3.1,<4.0a0|>=3.1.20170329,<3.2.0a0|>=3.1.20170329,<4.0a0|>=3.1.20191231,<3.2.0a0|>=3.1.20191231,<4.0a0|>=3.1.20210216,<3.2.0a0|>=3.1.20210216,<4.0a0|>=3.1.20181209,<3.2.0a0|>=3.1.20181209,<4.0a0']
# libcurl -> krb5[version='>=1.19.2,<1.20.0a0'] -> libedit[version='>=3.1.20170329,<3.2.0a0|>=3.1.20170329,<4.0a0|>=3.1.20191231,<3.2.0a0|>=3.1.20191231,<4.0a0|>=3.1.20210216,<3.2.0a0|>=3.1.20210216,<4.0a0|>=3.1.20181209,<3.2.0a0|>=3.1.20181209,<4.0a0']
#
# Package path conflicts for:
# path.py -> path[version='<13.2']
# anaconda==2021.11 -> path==16.0.0[build='py37hecd8cb5_0|py38hecd8cb5_0|py39hecd8cb5_0']
# anaconda==2021.11 -> path.py==12.5.0=hd3eb1b0_0 -> path
#
# Package pyqtchart conflicts for:
# anaconda-navigator -> pyqt[version='>=5.6,<6.0a0'] -> pyqtchart==5.12[build='py37h5ae2165_6|py36hb40023b_7|py37h5ae2165_7|py310hea9ccf3_8|py38hb240fba_8|py39he44290a_8|py37hab5ec1f_8|py38h721a93c_7|py39hef7122c_7|py36hb40023b_6|py39hef7122c_6|py38h721a93c_6|py38h721a93c_5']
# spyder -> pyqt[version='>=5.6,<5.13'] -> pyqtchart==5.12[build='py37h5ae2165_6|py36hb40023b_7|py37h5ae2165_7|py310hea9ccf3_8|py38hb240fba_8|py39he44290a_8|py37hab5ec1f_8|py38h721a93c_7|py39hef7122c_7|py36hb40023b_6|py39hef7122c_6|py38h721a93c_6|py38h721a93c_5']
# qtconsole -> pyqt -> pyqtchart==5.12[build='py37h5ae2165_6|py36hb40023b_7|py37h5ae2165_7|py310hea9ccf3_8|py38hb240fba_8|py39he44290a_8|py37hab5ec1f_8|py38h721a93c_7|py39hef7122c_7|py36hb40023b_6|py39hef7122c_6|py38h721a93c_6|py38h721a93c_5']
# pyqt -> pyqtchart==5.12[build='py37h5ae2165_6|py36hb40023b_7|py37h5ae2165_7|py310hea9ccf3_8|py38hb240fba_8|py39he44290a_8|py37hab5ec1f_8|py38h721a93c_7|py39hef7122c_7|py36hb40023b_6|py39hef7122c_6|py38h721a93c_6|py38h721a93c_5']
# navigator-updater -> pyqt[version='>=5.6'] -> pyqtchart==5.12[build='py37h5ae2165_6|py36hb40023b_7|py37h5ae2165_7|py310hea9ccf3_8|py38hb240fba_8|py39he44290a_8|py37hab5ec1f_8|py38h721a93c_7|py39hef7122c_7|py36hb40023b_6|py39hef7122c_6|py38h721a93c_6|py38h721a93c_5']
#
# Package libzopfli conflicts for:
# anaconda==2021.11 -> libzopfli==1.0.3=hb1e8313_0
# imagecodecs -> libzopfli[version='>=1.0.3,<1.1.0a0']
# tifffile -> imagecodecs[version='>=2021.7.30'] -> libzopfli[version='>=1.0.3,<1.1.0a0']
# anaconda==2021.11 -> imagecodecs==2021.8.26=py37ha952a84_0 -> libzopfli[version='>=1.0.3,<1.1.0a0']
#
# Package tinycss conflicts for:
# spyder -> qstylizer[version='>=0.1.10'] -> tinycss[version='>=0.4,<1.0']
# anaconda==2021.11 -> qstylizer==0.1.10=pyhd3eb1b0_0 -> tinycss[version='>=0.4,<1.0']
# qstylizer -> tinycss[version='>=0.4,<1.0']
# anaconda==2021.11 -> tinycss==0.4=pyhd3eb1b0_1002
#
# Package isl conflicts for:
# scipy -> libgcc -> isl
# giflib -> libgcc -> isl
#
# Package tomlkit conflicts for:
# jupyterlab_server -> jupyter-packaging[version='>=0.9,<2'] -> tomlkit
# jupyterlab -> jupyter-packaging[version='>=0.7,<1'] -> tomlkit
# jupyter_server -> jupyter-packaging[version='>=0.9,<1.0'] -> tomlkit
# black -> tomli[version='>=0.2.6,<2.0.0'] -> tomlkit
#
# Package json5 conflicts for:
# anaconda==2021.11 -> json5==0.9.6=pyhd3eb1b0_0
# anaconda==2021.11 -> jupyterlab_server==2.8.2=pyhd3eb1b0_0 -> json5
# jupyterlab -> jupyterlab_server[version='>=2.3,<3'] -> json5
# jupyterlab_server -> json5
#
# Package pathspec conflicts for:
# python-lsp-black -> black -> pathspec[version='>=0.6,<1|>=0.8.1,<1|>=0.9,<1']
# anaconda==2021.11 -> pathspec==0.7.0=py_0
# anaconda==2021.11 -> black==19.10b0=py_0 -> pathspec
# ipython -> black -> pathspec[version='>=0.6,<1|>=0.8.1,<1|>=0.9,<1']
# black -> pathspec[version='>=0.6,<1|>=0.8.1,<1|>=0.9,<1']
#
# Package libaec conflicts for:
# tifffile -> imagecodecs[version='>=2021.7.30'] -> libaec[version='>=1.0.4,<2.0a0|>=1.0.5,<2.0a0|>=1.0.6,<2.0a0']
# anaconda==2021.11 -> imagecodecs==2021.8.26=py37ha952a84_0 -> libaec[version='>=1.0.4,<2.0a0']
# imagecodecs -> libaec[version='>=1.0.4,<2.0a0|>=1.0.5,<2.0a0|>=1.0.6,<2.0a0']
# anaconda==2021.11 -> libaec==1.0.4=hb1e8313_1
#
# Package nspr conflicts for:
# qt -> nspr[version='>=4.20,<5.0a0|>=4.29,<5.0a0|>=4.32,<5.0a0']
# qt -> nss[version='>=3.47,<4.0a0'] -> nspr[version='>=4.22,<5.0a0|>=4.30,<5.0a0']
# pyqt -> qt[version='>=5.12.9,<5.13.0a0'] -> nspr[version='>=4.20,<5.0a0|>=4.29,<5.0a0|>=4.32,<5.0a0']
#
# Package jinja2-time conflicts for:
# cookiecutter -> jinja2-time[version='>=0.1.0|>=0.2.0']
# anaconda==2021.11 -> cookiecutter==1.7.2=pyhd3eb1b0_0 -> jinja2-time[version='>=0.2.0']
# spyder -> cookiecutter[version='>=1.6.0'] -> jinja2-time[version='>=0.1.0|>=0.2.0']
# anaconda==2021.11 -> jinja2-time==0.2.0=pyhd3eb1b0_2
#
# Package matplotlib conflicts for:
# anaconda==2021.11 -> astropy==4.3.1=py37hf9932de_0 -> matplotlib[version='>=2.2|>=3.0,!=3.4.0']
# anaconda==2021.11 -> matplotlib==3.4.3[build='py37hecd8cb5_0|py38hecd8cb5_0|py39hecd8cb5_0']
# distributed -> bokeh[version='>=0.12.3'] -> matplotlib
# scikit-image -> networkx[version='>=2.2'] -> matplotlib[version='>=3.3']
# nltk -> matplotlib
# scikit-image -> matplotlib[version='>=1.1|>=1.3.1|>=2.0.0']
# bokeh -> matplotlib
# prophet -> pystan~=2.19.1.1 -> matplotlib
# astropy -> matplotlib[version='>=3.0|>=3.0,!=3.4.0']
# dask -> bokeh -> matplotlib
# networkx -> matplotlib[version='>=3.3']
# seaborn -> matplotlib[version='>=1.4.3|>=2.1.2|>=2.2']
#
# Package jaraco.itertools conflicts for:
# importlib_metadata -> zipp[version='>=0.5'] -> jaraco.itertools
# zipp -> jaraco.itertools
# importlib-metadata -> zipp[version='>=0.5'] -> jaraco.itertools
#
# Package python-pathlib2 conflicts for:
# spyder -> pickleshare[version='>=0.4'] -> python-pathlib2
# ipython -> pickleshare -> python-pathlib2
# pickleshare -> python-pathlib2
#
# Package deprecation conflicts for:
# jupyterlab -> jupyter-packaging[version='>=0.7,<1'] -> deprecation
# jupyterlab_server -> jupyter-packaging[version='>=0.9,<2'] -> deprecation
# jupyter_server -> jupyter-packaging[version='>=0.9,<1.0'] -> deprecation
#
# Package backports.weakref conflicts for:
# conda-verify -> backports.tempfile -> backports.weakref
# backports.tempfile -> backports.weakref
#
# Package pyerfa conflicts for:
# anaconda==2021.11 -> pyerfa==2.0.0[build='py37h9ed2024_0|py38h9ed2024_0|py39h9ed2024_0']
# anaconda==2021.11 -> astropy==4.3.1=py37hf9932de_0 -> pyerfa[version='>=1.7.3']
# astropy -> pyerfa[version='>=1.7.3|>=2.0']
#
# Package locket conflicts for:
# anaconda==2021.11 -> partd==1.2.0=pyhd3eb1b0_0 -> locket
# dask -> partd[version='>=0.3.10'] -> locket
# dask-core -> partd[version='>=0.3.10'] -> locket
# distributed -> locket
# partd -> locket
# anaconda==2021.11 -> locket==0.2.1[build='py37hecd8cb5_1|py38hecd8cb5_1|py39hecd8cb5_1']
#
# Package scikit-learn conflicts for:
# anaconda==2021.11 -> scikit-learn-intelex==2021.3.0=py37hecd8cb5_0 -> scikit-learn[version='>=0.22']
# anaconda==2021.11 -> scikit-learn==0.24.2[build='py38hb2f4e1b_0|py37hb2f4e1b_0|py39hb2f4e1b_0']
# scikit-learn-intelex -> scikit-learn[version='>=0.21|>=0.22']
# nltk -> scikit-learn
#
# Package backports.tempfile conflicts for:
# conda-build -> conda-verify -> backports.tempfile
# scikit-image -> pooch[version='>=0.5.2'] -> backports.tempfile
# conda-verify -> backports.tempfile
#
# Package jupyterlab conflicts for:
# anaconda==2021.11 -> jupyterlab==3.2.1=pyhd3eb1b0_1
# _ipyw_jlab_nb_ext_conf -> jupyterlab
#
# Package unixodbc conflicts for:
# anaconda==2021.11 -> unixodbc==2.3.9=haf1e3a3_0
# anaconda==2021.11 -> pyodbc==4.0.31=py37h23ab428_0 -> unixodbc[version='>=2.3.9,<2.4.0a0']
# pyodbc -> unixodbc[version='2.3.4|2.3.4.*|>=2.3.5,<2.4.0a0|>=2.3.7,<2.4.0a0|>=2.3.9,<2.4.0a0|>=2.3.6,<2.4.0a0']
#
# Package tblib conflicts for:
# dask -> distributed=2022.1.0 -> tblib[version='>=1.6.0']
# anaconda==2021.11 -> tblib==1.7.0=pyhd3eb1b0_0
# anaconda==2021.11 -> distributed==2021.10.0=py37hecd8cb5_0 -> tblib[version='>=1.6.0']
# distributed -> tblib[version='>=1.6.0']
#
# Package libbrotlicommon conflicts for:
# imagecodecs -> libbrotlicommon[version='>=1.0.9,<1.1.0a0']
# tifffile -> imagecodecs[version='>=2021.7.30'] -> libbrotlicommon[version='>=1.0.9,<1.1.0a0']
# brotli -> libbrotlidec==1.0.9=h0d85af4_6 -> libbrotlicommon==1.0.9[build='h0d85af4_5|h0d85af4_6']
# imagecodecs -> libbrotlidec[version='>=1.0.9,<1.1.0a0'] -> libbrotlicommon==1.0.9[build='h0d85af4_5|h0d85af4_6']
#
# Package qtawesome conflicts for:
# anaconda==2021.11 -> qtawesome==1.0.2=pyhd3eb1b0_0
# spyder -> qtawesome[version='>=0.4.1|>=0.5.7|>=1.0.2']
# anaconda==2021.11 -> spyder==5.1.5=py37hecd8cb5_1 -> qtawesome[version='>=1.0.2']
#
# Package statsmodels conflicts for:
# seaborn -> statsmodels[version='>=0.5.0|>=0.8.0']
# anaconda==2021.11 -> statsmodels==0.12.2[build='py37h9ed2024_0|py38h9ed2024_0|py39h9ed2024_0']
#
# Package jxrlib conflicts for:
# anaconda==2021.11 -> jxrlib==1.1=haf1e3a3_2
# anaconda==2021.11 -> imagecodecs==2021.8.26=py37ha952a84_0 -> jxrlib[version='>=1.1,<1.2.0a0']
# tifffile -> imagecodecs[version='>=2021.7.30'] -> jxrlib[version='>=1.1,<1.2.0a0']
# imagecodecs -> jxrlib[version='>=1.1,<1.2.0a0']
#
# Package libuv conflicts for:
# gevent -> libuv[version='>=1.40.0,<2.0a0|>=1.41.0,<2.0a0|>=1.42.0,<2.0a0']
# anaconda==2021.11 -> libuv==1.40.0=haf1e3a3_0
# anaconda==2021.11 -> gevent==21.8.0=py37h9ed2024_1 -> libuv[version='>=1.40.0,<2.0a0']
#
# Package s3fs conflicts for:
# distributed -> s3fs[version='>=0.0.6|>=0.0.7|>=0.0.8']
# dask -> distributed[version='>=1.16.0'] -> s3fs[version='>=0.0.6|>=0.0.7|>=0.0.8']
#
# Package archspec conflicts for:
# conda-token -> conda[version='>=4.3'] -> archspec
# conda-build -> conda[version='>=4.5'] -> archspec
#
# Package trio conflicts for:
# anyio -> trio
# jupyter_server -> anyio[version='>=2.0.2,<3'] -> trio
#
# Package lz4 conflicts for:
# libarchive -> zstd[version='>=1.3.7,<1.3.8.0a0'] -> lz4
# libtiff -> zstd[version='>=1.3.7,<1.3.8.0a0'] -> lz4
# blosc -> zstd[version='>=1.3.7,<1.3.8.0a0'] -> lz4
# zstd -> lz4
#
# Package rtree conflicts for:
# spyder -> rtree[version='>=0.8.3|>=0.9.7']
# anaconda==2021.11 -> spyder==5.1.5=py37hecd8cb5_1 -> rtree[version='>=0.9.7']
# anaconda==2021.11 -> rtree==0.9.7[build='py37hecd8cb5_1|py38hecd8cb5_1|py39hecd8cb5_1']
#
# Package py-lief conflicts for:
# anaconda==2021.11 -> py-lief==0.10.1[build='py38haf313ee_0|py37haf313ee_0|py39h23ab428_1']
# conda-build -> py-lief
#
# Package libbrotlidec conflicts for:
# imagecodecs -> libbrotlidec[version='>=1.0.9,<1.1.0a0']
# imagecodecs -> brotli[version='>=1.0.9,<2.0a0'] -> libbrotlidec==1.0.9[build='h0d85af4_5|h0d85af4_6']
#
# Package daal4py conflicts for:
# anaconda==2021.11 -> scikit-learn-intelex==2021.3.0=py37hecd8cb5_0 -> daal4py=2021.3.0
# anaconda==2021.11 -> daal4py==2021.3.0[build='py39h01d92e1_0|py38h01d92e1_0|py37h01d92e1_0']
# scikit-learn-intelex -> daal4py[version='2021.2.2.*|2021.2.2|2021.2.3|2021.3.0|2021.4.0|2021.4.0.*|2021.3.0.*']
#
# Package twisted conflicts for:
# notebook -> prometheus_client -> twisted
# prometheus_client -> twisted
# jupyter_server -> prometheus_client -> twisted
#
# Package python-jsonrpc-server conflicts for:
# pyls-spyder -> python-language-server[version='>=0.36.2'] -> python-jsonrpc-server[version='>=0.1.0|>=0.3.2|>=0.4.0']
# spyder -> python-language-server[version='>=0.36.2,<1.0.0'] -> python-jsonrpc-server[version='>=0.3.2|>=0.4.0']
#
# Package pympler conflicts for:
# spyder -> pympler
# pytest -> attrs[version='>=17.2.0'] -> pympler
# attrs -> pympler
#
# Package fastcache conflicts for:
# sympy -> fastcache
# anaconda==2021.11 -> fastcache==1.1.0[build='py37h1de35cc_0|py38h1de35cc_0|py39h9ed2024_0']
# Note: you may need to restart the kernel to use updated packages.
